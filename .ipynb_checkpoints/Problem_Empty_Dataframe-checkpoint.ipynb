# %% [markdown]
# # Drinks and Meals

# %%
import pandas as pd
import requests
import json
import matplotlib
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999
pd.set_option("display.max_colwidth", -1)

# %matplotlib inline

# %%
ingridient_df = ""
category_df = ""
area_df = ""

# %% [markdown]
# ## Start function

# %%
#this function start the program calling the other functions

def start():
    print("welcome to your night what do you want to do drink or meal?")
    x = input().strip().lower()
    if x == "drinks" or x == "drink":
        return drink_option_choose()
    elif x == "meals" or x == "meal":
        return meal_option_choose()
    else:
        print("Sorry please choose a valide option")
        return start()

# %% [markdown]
# ## Drinks functions

# %% [markdown]
# ### Choose drink options

# %%
def drink_option_choose():
    print("""do you want to search by?
Name, Main ingridient, Category
    """)
    x = input().strip().lower()
    if x == "name":
        return drink_name_choose()
    elif x == "ingridient":
        return drink_ingridient_choose()
    elif x == "category":
        return drink_category_choose()
    else:
        print("Sorry please choose a valide option")
        return drink_option_choose()

# %% [markdown]
# ### Drink name

# %%
def drink_name_choose():
    print("""Choose your drink name
    """)
    x = input().strip().lower()
    return drink(x)

def drink(name):
    global ingridient_df
    url = f"https://www.thecocktaildb.com/api/json/v1/1/search.php?s={str(name)}"
    r = requests.get(url)
    df = pd.DataFrame(r.json()["drinks"])
    ingridient_df = df
    if df.empty == True:
        print("There are no matching names")
        drink_name_choose()
    else:
        display(df.dropna(axis='columns', how='all'))
    
    
    
    #changes
        if df.empty == True: 
            print("There are no matching drink names")
            return drink_name_choose()
        else:
            print("These are the items that match with your search. Please select a row to inspect.")
        
            x = input().strip().lower()
            try: 
                if int(x) <= len(ingridient_df):
                    return drink_id(x)
                elif int(x) > len(ingridient_df):
                    return drink(name)
            except:
                print("Please choose a number inside of the index")
                return drink(name)

# %% [markdown]
# ### Drink ingridient

# %%
def drink_ingridient_choose():
    print("""Choose your main ingridient
    """)
    x = input().strip().lower()
    
    
    #changes
    try:
        return drink_main(x)
    except: 
        print("There is no matching ingredient.")
        return drink_ingridient_choose()

def drink_main(main):
    global ingridient_df
    url = f"https://www.thecocktaildb.com/api/json/v1/1/filter.php?i={str(main)}"
    r = requests.get(url)
    df = pd.DataFrame(r.json()["drinks"])
    display(df.dropna(axis='columns', how='all')["strDrink"].to_frame())
    ingridient_df = df
    return drink_id_choose()

# %% [markdown]
# ### Drink category

# %%
# Search for drink category
def drink_category_choose():
    global category_df
    print("""this are the categories please choose the row you want to inspect
    """)
    url_list_origin = "https://www.thecocktaildb.com/api/json/v1/1/list.php?c=list"
    ra = requests.get(url_list_origin)
    df = pd.DataFrame(ra.json()["drinks"])
    category_df = df
    display(df)
    x = input().strip().lower()
    try: 
        if int(x) <= len(category_df):
            return drink_category_row(x)
        elif int(x) > len(category_df):
            return drink_category_choose()
    except:
        print("Please choose a number inside of the index")
        return drink_category_choose()

def drink_category_row(x):
    global category_df
    global ingridient_df
    category = category_df.loc[int(x), "strCategory"]
    url = f"https://www.thecocktaildb.com/api/json/v1/1/filter.php?c={str(category)}"
    r = requests.get(url)
    dfcat = pd.DataFrame(r.json()["drinks"])
    ingridient_df = dfcat
    display(dfcat.dropna(axis='columns', how='all'))#.drop(columns=['strInstructions','strInstructionsDE','strCreativeCommonsConfirmed'], axis=1).transpose()
    return drink_id_choose()

# %% [markdown]
# ### Drink id

# %%
def drink_id_choose():
    print("""Choose the row you want to examine
    """)
    x = input().strip().lower()
    #changes
    try: 
        if int(x) <= len(ingridient_df):
            return drink_id(x)
        elif int(x) > len(ingridient_df):
            print("please choose a number inside of the index")
            return drink_id_choose()
    except:
        print("please choose a number inside of the index")
        return drink_id_choose()

def drink_id(x):
    global ingridient_df
    id = ingridient_df.loc[int(x), "idDrink"]
    url = f"https://www.thecocktaildb.com/api/json/v1/1/lookup.php?i={id}"
    r = requests.get(url)
    dfid = pd.DataFrame(r.json()["drinks"])
    display(dfid["strInstructions"].to_frame())
    display(dfid.dropna(axis='columns', how='all').drop(columns=['strInstructions','strInstructionsDE','strCreativeCommonsConfirmed'], axis=1).transpose())
    return restart()

# %% [markdown]
# ## Meals Functions

# %% [markdown]
# ### Choose meals options

# %%
def meal_choose():
    print("what do you want to eat?")
    x = input("meal").strip().lower()
    return meal(x)

def meal_option_choose():
    print("""do you want to search by?
Name, Main ingridient, Category, Area
    """)
    x = input().strip().lower()
    if x == "name" or x == "names":
        return meal_name_choose()
    elif x == "ingridient" or x == "main" or x == "main ingridient":
        return meal_ingridient_choose()
    elif x == "category" or x == "categories":
        return meal_category_choose()
    elif x == "area":
        return meal_area_choose()
    else:
        print("Sorry please choose a valide option")
        return meal_option_choose()

# %% [markdown]
# ### Name

# %%
def meal_name_choose():
    print("""Choose your meal name
    """)
    x = input().strip().lower()
    return meal(x)

def meal(name):
    global ingridient_df
    url = f"https://www.themealdb.com/api/json/v1/1/search.php?s={str(name)}"
    r = requests.get(url)
    df = pd.DataFrame(r.json()["meals"])
    ingridient_df = df
    if df.empty == True:
        print("There are no matching names")
        meal_name_choose()
    else:
        display(df.dropna(axis='columns', how='all'))
    
    
    
    #changes
        if df.empty == True: 
            print("There are no matching meal names")
            return meal_name_choose()
        else:
            print("These are the items that match with your search. Please select a row to inspect.")
        
            x = input().strip().lower()
            try: 
                if int(x) <= len(ingridient_df):
                    return meal_id(x)
                elif int(x) > len(ingridient_df):
                    return meal(name)
            except:
                print("Please choose a number inside of the index")
                return meal(name)

# %% [markdown]
# ### Meal ingridient

# %%
def meal_ingridient_choose():
    print("""Choose your main ingridient
    """)
    x = input().strip().lower()
    
    
        #changes
    try:
        return meal_main(x)
    except: 
        print("There is no matching ingredient.")
        return meal_ingridient_choose()

def meal_main(main):
    global ingridient_df
    url = f"https://www.themealdb.com/api/json/v1/1/filter.php?i={str(main)}"
    r = requests.get(url)
    df = pd.DataFrame(r.json()["meals"])
    display(df.dropna(axis='columns', how='all')["strMeal"].to_frame())
    ingridient_df = df
    return meal_id_choose()

# %% [markdown]
# ### Meal category

# %%
def meal_category_choose():
    global category_df
    print("""this are the categories please choose the row you want to inspect
    """)
    url_list_origin = "https://www.themealdb.com/api/json/v1/1/list.php?c=list"
    ra = requests.get(url_list_origin)
    df = pd.DataFrame(ra.json()["meals"])
    category_df = df
    display(df)
    x = input().strip().lower()
    
    
    #changes
    try: 
        if int(x) <= len(df):
            return meal_category_row(x)
        elif int(x) > len(df):
            return meal_category_choose()
    except:
        print("Please choose a number inside of the index")
        return meal_category_choose()

def meal_category_row(x):
    global category_df
    global ingridient_df
    category = category_df.loc[int(x), "strCategory"]
    url = f"https://www.themealdb.com/api/json/v1/1/filter.php?c={str(category)}"
    r = requests.get(url)
    dfcat = pd.DataFrame(r.json()["meals"])
    ingridient_df = dfcat
    display(dfcat.dropna(axis='columns', how='all'))#.drop(columns=['strInstructions','strInstructionsDE','strCreativeCommonsConfirmed'], axis=1).transpose()
    return meal_id_choose()

# %% [markdown]
# ### Meal area

# %%
def meal_area_choose():
    global area_df
    print("""this are the areas please choose the row you want to inspect
    """)
    url_list_origin = "https://www.themealdb.com/api/json/v1/1/list.php?a=list"
    ra = requests.get(url_list_origin)
    df = pd.DataFrame(ra.json()["meals"])
    area_df = df
    display(df)
    x = input().strip().lower()
    
    #changes
    try: 
        if int(x) <= len(df):
            return meal_area_row(x)
        elif int(x) > len(df):
            return meal_area_choose()
    except:
        print("Please choose a number inside of the index")
        return meal_area_choose()

def meal_area_row(x):
    global area_df
    global ingridient_df
    area = area_df.loc[int(x), "strArea"]
    url = f"https://www.themealdb.com/api/json/v1/1/filter.php?a={str(area)}"
    r = requests.get(url)
    dfa = pd.DataFrame(r.json()["meals"])
    ingridient_df = dfa
    display(dfa.dropna(axis='columns', how='all'))#.drop(columns=['strInstructions','strInstructionsDE','strCreativeCommonsConfirmed'], axis=1).transpose()
    return meal_id_choose()

# %% [markdown]
# ### Meal id

# %%
def meal_id_choose():
    global ingridient_df
    print("""Choose the row you want to examine
    """)
    x = input().strip().lower()
    #changes
    try: 
        if int(x) <= len(ingridient_df):
            return meal_id(x)
        elif int(x) > len(ingridient_df):
            print("please choose a number inside of the index")
            return meal_id_choose()
    except:
        print("please choose a number inside of the index")
        return meal_id_choose()
    
def meal_id(x):
    global ingridient_df
    id = ingridient_df.loc[int(x), "idMeal"]
    url = f"https://www.themealdb.com/api/json/v1/1/lookup.php?i={id}"
    r = requests.get(url)
    dfid = pd.DataFrame(r.json()["meals"])
    display(dfid["strInstructions"].to_frame())
    display(dfid.dropna(axis='columns', how='all').drop(columns=['strInstructions'], axis=1).transpose())
    return restart()

# %% [markdown]
# ## Restart or break

# %%
def restart():
    global ingridient_df
    global category_df
    global area_df
    print("do you want to restart the game? (Yes/No)") #changes
    x = input().strip().lower()
    if x == "yes":
        ingridient_df = ""
        category_df = ""
        area_df = ""
        return start()
    elif x == "no":
        return ("Have a nice evening")
    else:
        return restart()

# %% [markdown]
# # This function start everything

# %%
start()
# Out:
# welcome to your night what do you want to do drink or meal?
# meal
# do you want to search by?
# Name, Main ingridient, Category, Area
#
# name
# Choose your meal name
#
# spa
#   idMeal                   strMeal strCategory  strArea  \
# 0  52872  Spanish Tortilla          Vegetarian  Spanish
# 1  52770  Spaghetti Bolognese       Beef        Italian
# 2  52982  Spaghetti alla Carbonara  Pasta       Italian
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          strInstructions  \
# 0  Put a large non-stick frying pan on a low heat. Cook the onion slowly in the oil and butter until soft but not brown – this should take about 15 mins. Add the potatoes, cover the pan and cook for a further 15-20 mins, stirring occasionally to make sure they fry evenly.\r\nWhen the potatoes are soft and the onion is shiny, crush 2 garlic cloves and stir in, followed by the beaten eggs.\r\nPut the lid back on the pan and leave the tortilla to cook gently. After 20 mins, the edges and base should be golden, the top set but the middle still a little wobbly. To turn it over, slide it onto a plate and put another plate on top, turn the whole thing over and slide it back into the pan to finish cooking. Once cooked, transfer to a plate and serve the tortilla warm or cold, scattered with the chopped parsley.\r\nTo accompany, take slices of warmed baguette, stab all over with a fork and rub with the remaining garlic, pile on grated tomatoes and season with sea salt and a drizzle of olive oil.
# 1  Put the onion and oil in a large pan and fry over a fairly high heat for 3-4 mins. Add the garlic and mince and fry until they both brown. Add the mushrooms and herbs, and cook for another couple of mins.\r\n\r\nStir in the tomatoes, beef stock, tomato ketchup or purée, Worcestershire sauce and seasoning. Bring to the boil, then reduce the heat, cover and simmer, stirring occasionally, for 30 mins.\r\n\r\nMeanwhile, cook the spaghetti in a large pan of boiling, salted water, according to packet instructions. Drain well, run hot water through it, put it back in the pan and add a dash of olive oil, if you like, then stir in the meat sauce. Serve in hot bowls and hand round Parmesan cheese, for sprinkling on top.
# 2  Per preparare gli spaghetti alla carbonara cominciate mettendo sul fuoco una pentola con l’acqua salata per cuocere la pasta. Nel frattempo eliminate la cotenna dal guanciale  e tagliatelo prima a fette e poi a striscioline spesse circa 1cm . La cotenna avanzata potrà essere riutilizzata per insaporire altre preparazioni. Versate i pezzetti in una padella antiaderente e rosolate per circa 15 minuti a fiamma media, fate attenzione a non bruciarlo altrimenti rilascerà un aroma troppo forte.\r\n\r\nNel frattempo tuffate gli spaghetti nell’acqua bollente e cuoceteli per il tempo indicato sulla confezione. Intanto versate i tuorli in una ciotola, aggiungete anche la maggior parte del pecorino previsto dalla ricetta la parte restante servirà per guarnire la pasta.\r\n\r\nInsaporite con il pepe nero, amalgamate tutto con una frusta a mano. Aggiungete un cucchiaio di acqua di cottura per diluire il composto e mescolate.\r\n\r\n\r\nIntanto il guanciale sarà giunto a cottura, spegnete il fuoco e tenetelo da parte. Scolate la pasta al dente direttamente nel tegame con il guanciale e saltatela brevemente per insaporirla. Togliete dal fuoco e versate il composto di uova e pecorino nel tegame, saltate la pasta per amalgamare\r\n\r\n\r\ne se dovesse risultare troppo asciutta potete aggiungere poca acqua di cottura. Servite subito gli spaghetti alla carbonara insaporendoli con il pecorino avanzato e il pepe nero macinato.
#
#                                                         strMealThumb  \
# 0  https://www.themealdb.com/images/media/meals/quuxsx1511476154.jpg
# 1  https://www.themealdb.com/images/media/meals/sutysw1468247559.jpg
# 2  https://www.themealdb.com/images/media/meals/llcbn01574260722.jpg
#
#                strTags                                   strYoutube  \
# 0  Egg,Light            https://www.youtube.com/watch?v=JceGMNG7rpU
# 1  Pasta,Meat           https://www.youtube.com/watch?v=-gF8d-fitkU
# 2  Pasta,BBQ,Breakfast  https://www.youtube.com/watch?v=_T6jkRvhlkk
#
#   strIngredient1 strIngredient2 strIngredient3    strIngredient4  \
# 0  Onion          Olive Oil      Butter         Potatoes
# 1  onions         olive oil      garlic         lean minced beef
# 2  Spaghetti      Egg Yolks      Salt           Bacon
#
#   strIngredient5 strIngredient6 strIngredient7  strIngredient8 strIngredient9  \
# 0  Garlic         Eggs           Parsley        Baguette        Vine Tomatoes
# 1  mushrooms      dried oregano  tomatoes       hot beef stock  tomato puree
# 2  Pecorino       Black Pepper
#
#         strIngredient10 strIngredient11 strIngredient12 strIngredient13  \
# 0  Olive Oil
# 1  worcestershire sauce  spaghetti       parmesan        None
# 2
#
#   strIngredient14 strIngredient15 strIngredient16 strIngredient17  \
# 0
# 1  None            None            None            None
# 2
#
#   strIngredient18 strIngredient19 strIngredient20 strMeasure1 strMeasure2  \
# 0                                                  1 sliced    4 tbsp
# 1  None            None            None            2           1tbsp
# 2                                                  320g        6
#
#    strMeasure3 strMeasure4 strMeasure5  strMeasure6 strMeasure7 strMeasure8  \
# 0  25g          400g        6 cloves    8            Handful     1
# 1  1 clove      500g        90g         1tsp         400g can    300ml
# 2  As required  150g        50g         As required
#
#   strMeasure9 strMeasure10 strMeasure11 strMeasure12 strMeasure13  \
# 0  4           drizzle
# 1  1tbsp       1tbsp        350g         Topping
# 2
#
#   strMeasure14 strMeasure15 strMeasure16 strMeasure17 strMeasure18  \
# 0
# 1                            None         None         None
# 2
#
#   strMeasure19 strMeasure20  \
# 0
# 1  None         None
# 2
#
#                                                           strSource
# 0  https://www.bbcgoodfood.com/recipes/spanish-tortilla
# 1  None
# 2  https://ricette.giallozafferano.it/Spaghetti-alla-Carbonara.html
# These are the items that match with your search. Please select a row to inspect.
# 3
# Please choose a number inside of the index
#   idMeal                   strMeal strCategory  strArea  \
# 0  52872  Spanish Tortilla          Vegetarian  Spanish
# 1  52770  Spaghetti Bolognese       Beef        Italian
# 2  52982  Spaghetti alla Carbonara  Pasta       Italian
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          strInstructions  \
# 0  Put a large non-stick frying pan on a low heat. Cook the onion slowly in the oil and butter until soft but not brown – this should take about 15 mins. Add the potatoes, cover the pan and cook for a further 15-20 mins, stirring occasionally to make sure they fry evenly.\r\nWhen the potatoes are soft and the onion is shiny, crush 2 garlic cloves and stir in, followed by the beaten eggs.\r\nPut the lid back on the pan and leave the tortilla to cook gently. After 20 mins, the edges and base should be golden, the top set but the middle still a little wobbly. To turn it over, slide it onto a plate and put another plate on top, turn the whole thing over and slide it back into the pan to finish cooking. Once cooked, transfer to a plate and serve the tortilla warm or cold, scattered with the chopped parsley.\r\nTo accompany, take slices of warmed baguette, stab all over with a fork and rub with the remaining garlic, pile on grated tomatoes and season with sea salt and a drizzle of olive oil.
# 1  Put the onion and oil in a large pan and fry over a fairly high heat for 3-4 mins. Add the garlic and mince and fry until they both brown. Add the mushrooms and herbs, and cook for another couple of mins.\r\n\r\nStir in the tomatoes, beef stock, tomato ketchup or purée, Worcestershire sauce and seasoning. Bring to the boil, then reduce the heat, cover and simmer, stirring occasionally, for 30 mins.\r\n\r\nMeanwhile, cook the spaghetti in a large pan of boiling, salted water, according to packet instructions. Drain well, run hot water through it, put it back in the pan and add a dash of olive oil, if you like, then stir in the meat sauce. Serve in hot bowls and hand round Parmesan cheese, for sprinkling on top.
# 2  Per preparare gli spaghetti alla carbonara cominciate mettendo sul fuoco una pentola con l’acqua salata per cuocere la pasta. Nel frattempo eliminate la cotenna dal guanciale  e tagliatelo prima a fette e poi a striscioline spesse circa 1cm . La cotenna avanzata potrà essere riutilizzata per insaporire altre preparazioni. Versate i pezzetti in una padella antiaderente e rosolate per circa 15 minuti a fiamma media, fate attenzione a non bruciarlo altrimenti rilascerà un aroma troppo forte.\r\n\r\nNel frattempo tuffate gli spaghetti nell’acqua bollente e cuoceteli per il tempo indicato sulla confezione. Intanto versate i tuorli in una ciotola, aggiungete anche la maggior parte del pecorino previsto dalla ricetta la parte restante servirà per guarnire la pasta.\r\n\r\nInsaporite con il pepe nero, amalgamate tutto con una frusta a mano. Aggiungete un cucchiaio di acqua di cottura per diluire il composto e mescolate.\r\n\r\n\r\nIntanto il guanciale sarà giunto a cottura, spegnete il fuoco e tenetelo da parte. Scolate la pasta al dente direttamente nel tegame con il guanciale e saltatela brevemente per insaporirla. Togliete dal fuoco e versate il composto di uova e pecorino nel tegame, saltate la pasta per amalgamare\r\n\r\n\r\ne se dovesse risultare troppo asciutta potete aggiungere poca acqua di cottura. Servite subito gli spaghetti alla carbonara insaporendoli con il pecorino avanzato e il pepe nero macinato.
#
#                                                         strMealThumb  \
# 0  https://www.themealdb.com/images/media/meals/quuxsx1511476154.jpg
# 1  https://www.themealdb.com/images/media/meals/sutysw1468247559.jpg
# 2  https://www.themealdb.com/images/media/meals/llcbn01574260722.jpg
#
#                strTags                                   strYoutube  \
# 0  Egg,Light            https://www.youtube.com/watch?v=JceGMNG7rpU
# 1  Pasta,Meat           https://www.youtube.com/watch?v=-gF8d-fitkU
# 2  Pasta,BBQ,Breakfast  https://www.youtube.com/watch?v=_T6jkRvhlkk
#
#   strIngredient1 strIngredient2 strIngredient3    strIngredient4  \
# 0  Onion          Olive Oil      Butter         Potatoes
# 1  onions         olive oil      garlic         lean minced beef
# 2  Spaghetti      Egg Yolks      Salt           Bacon
#
#   strIngredient5 strIngredient6 strIngredient7  strIngredient8 strIngredient9  \
# 0  Garlic         Eggs           Parsley        Baguette        Vine Tomatoes
# 1  mushrooms      dried oregano  tomatoes       hot beef stock  tomato puree
# 2  Pecorino       Black Pepper
#
#         strIngredient10 strIngredient11 strIngredient12 strIngredient13  \
# 0  Olive Oil
# 1  worcestershire sauce  spaghetti       parmesan        None
# 2
#
#   strIngredient14 strIngredient15 strIngredient16 strIngredient17  \
# 0
# 1  None            None            None            None
# 2
#
#   strIngredient18 strIngredient19 strIngredient20 strMeasure1 strMeasure2  \
# 0                                                  1 sliced    4 tbsp
# 1  None            None            None            2           1tbsp
# 2                                                  320g        6
#
#    strMeasure3 strMeasure4 strMeasure5  strMeasure6 strMeasure7 strMeasure8  \
# 0  25g          400g        6 cloves    8            Handful     1
# 1  1 clove      500g        90g         1tsp         400g can    300ml
# 2  As required  150g        50g         As required
#
#   strMeasure9 strMeasure10 strMeasure11 strMeasure12 strMeasure13  \
# 0  4           drizzle
# 1  1tbsp       1tbsp        350g         Topping
# 2
#
#   strMeasure14 strMeasure15 strMeasure16 strMeasure17 strMeasure18  \
# 0
# 1                            None         None         None
# 2
#
#   strMeasure19 strMeasure20  \
# 0
# 1  None         None
# 2
#
#                                                           strSource
# 0  https://www.bbcgoodfood.com/recipes/spanish-tortilla
# 1  None
# 2  https://ricette.giallozafferano.it/Spaghetti-alla-Carbonara.html
# These are the items that match with your search. Please select a row to inspect.
# 2
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          strInstructions
# 0  Per preparare gli spaghetti alla carbonara cominciate mettendo sul fuoco una pentola con l’acqua salata per cuocere la pasta. Nel frattempo eliminate la cotenna dal guanciale  e tagliatelo prima a fette e poi a striscioline spesse circa 1cm . La cotenna avanzata potrà essere riutilizzata per insaporire altre preparazioni. Versate i pezzetti in una padella antiaderente e rosolate per circa 15 minuti a fiamma media, fate attenzione a non bruciarlo altrimenti rilascerà un aroma troppo forte.\r\n\r\nNel frattempo tuffate gli spaghetti nell’acqua bollente e cuoceteli per il tempo indicato sulla confezione. Intanto versate i tuorli in una ciotola, aggiungete anche la maggior parte del pecorino previsto dalla ricetta la parte restante servirà per guarnire la pasta.\r\n\r\nInsaporite con il pepe nero, amalgamate tutto con una frusta a mano. Aggiungete un cucchiaio di acqua di cottura per diluire il composto e mescolate.\r\n\r\n\r\nIntanto il guanciale sarà giunto a cottura, spegnete il fuoco e tenetelo da parte. Scolate la pasta al dente direttamente nel tegame con il guanciale e saltatela brevemente per insaporirla. Togliete dal fuoco e versate il composto di uova e pecorino nel tegame, saltate la pasta per amalgamare\r\n\r\n\r\ne se dovesse risultare troppo asciutta potete aggiungere poca acqua di cottura. Servite subito gli spaghetti alla carbonara insaporendoli con il pecorino avanzato e il pepe nero macinato.
#                                                                                  0
# idMeal           52982
# strMeal          Spaghetti alla Carbonara
# strCategory      Pasta
# strArea          Italian
# strMealThumb     https://www.themealdb.com/images/media/meals/llcbn01574260722.jpg
# strTags          Pasta,BBQ,Breakfast
# strYoutube       https://www.youtube.com/watch?v=_T6jkRvhlkk
# strIngredient1   Spaghetti
# strIngredient2   Egg Yolks
# strIngredient3   Salt
# strIngredient4   Bacon
# strIngredient5   Pecorino
# strIngredient6   Black Pepper
# strIngredient7
# strIngredient8
# strIngredient9
# strIngredient10
# strIngredient11
# strIngredient12
# strIngredient13
# strIngredient14
# strIngredient15
# strIngredient16
# strIngredient17
# strIngredient18
# strIngredient19
# strIngredient20
# strMeasure1      320g
# strMeasure2      6
# strMeasure3      As required
# strMeasure4      150g
# strMeasure5      50g
# strMeasure6      As required
# strMeasure7
# strMeasure8
# strMeasure9
# strMeasure10
# strMeasure11
# strMeasure12
# strMeasure13
# strMeasure14
# strMeasure15
# strMeasure16
# strMeasure17
# strMeasure18
# strMeasure19
# strMeasure20
# strSource        https://ricette.giallozafferano.it/Spaghetti-alla-Carbonara.html
# do you want to restart the game? (Yes/No)
# no
# 'Have a nice evening'
