# %%
import pandas as pd
import requests
import json
import matplotlib
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

# %matplotlib inline

# %%
url = "https://www.thecocktaildb.com/api/json/v1/1/search.php?s=kami"

# %%
rd = requests.get(url)

# %%
rd.json()["drinks"]
# Out:
# [{'idDrink': '11600',
#   'strDrink': 'Kamikaze',
#   'strDrinkAlternate': None,
#   'strDrinkES': None,
#   'strDrinkDE': None,
#   'strDrinkFR': None,
#   'strDrinkZH-HANS': None,
#   'strDrinkZH-HANT': None,
#   'strTags': 'IBA,NewEra',
#   'strVideo': None,
#   'strCategory': 'Ordinary Drink',
#   'strIBA': 'New Era Drinks',
#   'strAlcoholic': 'Alcoholic',
#   'strGlass': 'Cocktail glass',
#   'strInstructions': 'Shake all ingredients together with ice. Strain into glass, garnish and serve.',
#   'strInstructionsES': None,
#   'strInstructionsDE': 'Alle Zutaten zusammen mit Eis schütteln. In ein Glas abseihen, garnieren und servieren.',
#   'strInstructionsFR': None,
#   'strInstructionsZH-HANS': None,
#   'strInstructionsZH-HANT': None,
#   'strDrinkThumb': 'https://www.thecocktaildb.com/images/media/drink/xa58bb1504373204.jpg',
#   'strIngredient1': 'Vodka',
#   'strIngredient2': 'Triple sec',
#   'strIngredient3': 'Lime juice',
#   'strIngredient4': None,
#   'strIngredient5': None,
#   'strIngredient6': None,
#   'strIngredient7': None,
#   'strIngredient8': None,
#   'strIngredient9': None,
#   'strIngredient10': None,
#   'strIngredient11': None,
#   'strIngredient12': None,
#   'strIngredient13': None,
#   'strIngredient14': None,
#   'strIngredient15': None,
#   'strMeasure1': '1 oz ',
#   'strMeasure2': '1 oz ',
#   'strMeasure3': '1 oz ',
#   'strMeasure4': None,
#   'strMeasure5': None,
#   'strMeasure6': None,
#   'strMeasure7': None,
#   'strMeasure8': None,
#   'strMeasure9': None,
#   'strMeasure10': None,
#   'strMeasure11': None,
#   'strMeasure12': None,
#   'strMeasure13': None,
#   'strMeasure14': None,
#   'strMeasure15': None,
#   'strCreativeCommonsConfirmed': 'No',
#   'dateModified': '2017-09-02 18:26:44'}]

# %%
dfd = pd.DataFrame(rd.json()["drinks"])

# %%
dfd.dropna(axis='columns', how='all')
# Out:
#   idDrink  strDrink     strTags     strCategory          strIBA strAlcoholic  \
# 0   11600  Kamikaze  IBA,NewEra  Ordinary Drink  New Era Drinks    Alcoholic
#
#          strGlass                                    strInstructions  \
# 0  Cocktail glass  Shake all ingredients together with ice. Strai...
#
#                                    strInstructionsDE  \
# 0  Alle Zutaten zusammen mit Eis schütteln. In ei...
#
#                                        strDrinkThumb strIngredient1  \
# 0  https://www.thecocktaildb.com/images/media/dri...          Vodka
#
#   strIngredient2 strIngredient3 strMeasure1 strMeasure2 strMeasure3  \
# 0     Triple sec     Lime juice       1 oz        1 oz        1 oz
#
#   strCreativeCommonsConfirmed         dateModified
# 0                          No  2017-09-02 18:26:44

# %%
def drinks_ing(name):
    url = f"https://www.thecocktaildb.com/api/json/v1/1/filter.php?i={str(name)}"
    r = requests.get(url)
    dfd = pd.DataFrame(r.json()["drinks"])
    return dfd.dropna(axis='columns', how='all')

# %%
ing = input("Enter your given ingridient.")
# Out:
# Enter your given ingridient.water

# %%
drinks_ing(ing)
# Out:
#                         strDrink  \
# 0                   Adam Sunrise
# 1              Aloha Fruit punch
# 2               Amaretto Liqueur
# 3                  Bourbon Sling
# 4                Chocolate Drink
# 5          Classic Old-Fashioned
# 6                   Coffee-Vodka
# 7                Creme de Menthe
# 8                      Gin Toddy
# 9                      Gluehwein
# 10                   Iced Coffee
# 11               Jamaican Coffee
# 12                   Jello shots
# 13        Kill the cold Smoothie
# 14  Lassi - A South Indian Drink
# 15                 Lassi - Sweet
# 16                   Lassi Khara
# 17                   Lemouroudji
# 18                   Masala Chai
# 19                   Mulled Wine
# 20                  Shark Attack
# 21            Strawberry Shivers
# 22                 Sweet Sangria
# 23                 Thai Iced Tea
# 24                     Tia-Maria
#
#                                         strDrinkThumb idDrink
# 0   https://www.thecocktaildb.com/images/media/dri...   15567
# 1   https://www.thecocktaildb.com/images/media/dri...   12862
# 2   https://www.thecocktaildb.com/images/media/dri...   12792
# 3   https://www.thecocktaildb.com/images/media/dri...   11146
# 4   https://www.thecocktaildb.com/images/media/dri...   12734
# 5   https://www.thecocktaildb.com/images/media/dri...   11145
# 6   https://www.thecocktaildb.com/images/media/dri...   12800
# 7   https://www.thecocktaildb.com/images/media/dri...   12808
# 8   https://www.thecocktaildb.com/images/media/dri...   11420
# 9   https://www.thecocktaildb.com/images/media/dri...   12944
# 10  https://www.thecocktaildb.com/images/media/dri...   12770
# 11  https://www.thecocktaildb.com/images/media/dri...   15825
# 12  https://www.thecocktaildb.com/images/media/dri...   14956
# 13  https://www.thecocktaildb.com/images/media/dri...   12720
# 14  https://www.thecocktaildb.com/images/media/dri...   12690
# 15  https://www.thecocktaildb.com/images/media/dri...   12696
# 16  https://www.thecocktaildb.com/images/media/dri...   12692
# 17  https://www.thecocktaildb.com/images/media/dri...   12702
# 18  https://www.thecocktaildb.com/images/media/dri...   12774
# 19  https://www.thecocktaildb.com/images/media/dri...   12988
# 20  https://www.thecocktaildb.com/images/media/dri...   16273
# 21  https://www.thecocktaildb.com/images/media/dri...   12722
# 22  https://www.thecocktaildb.com/images/media/dri...   13024
# 23  https://www.thecocktaildb.com/images/media/dri...   12786
# 24  https://www.thecocktaildb.com/images/media/dri...   12856

# %%
inp = input("Enter the Cocktailnumber to see the recipe.")
# Out:
# Enter the Cocktailnumber to see the recipe.21

# %%
id = drinks_ing(ing).loc[int(inp), "idDrink"]

# %%
id
# Out:
# '12722'

# %%
def drink_id(name):
    url = f"https://www.thecocktaildb.com/api/json/v1/1/lookup.php?i={name}"
    r = requests.get(url)
    dfid = pd.DataFrame(r.json()["drinks"])
    return dfid.dropna(axis='columns', how='all')

# %%
drink_id(id)
# Out:
#   idDrink            strDrink    strCategory   strAlcoholic        strGlass  \
# 0   12722  Strawberry Shivers  Other/Unknown  Non alcoholic  Highball glass
#
#                                      strInstructions  \
# 0  Place all ingredients in the blender jar - cov...
#
#                                    strInstructionsDE  \
# 0  Alle Zutaten in den Mixer geben - abdecken und...
#
#                                        strDrinkThumb strIngredient1  \
# 0  https://www.thecocktaildb.com/images/media/dri...   Strawberries
#
#   strIngredient2 strIngredient3 strMeasure1 strMeasure2 strMeasure3  \
# 0          Honey          Water  1 1/2 cup       4 tsp     1/2 cup
#
#   strCreativeCommonsConfirmed         dateModified
# 0                          No  2017-02-20 15:10:04
