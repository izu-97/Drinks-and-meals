# %% [markdown]
# ## Function to get user selection of the category of the drink and provide list of options

# %%
import pandas as pd
import requests
import json
import matplotlib
#pd.options.display.max_rows = 999
#pd.options.display.max_columns = 999

# %matplotlib inline

# %%
# Search for drink category
def drink_category(category):
    url = f"https://www.thecocktaildb.com/api/json/v1/1/filter.php?c={str(category)}"
    r = requests.get(url)
    df = pd.DataFrame(r.json()["drinks"])
    return df.dropna(axis='columns', how='all')

# %%
drink_category("Soft Drink / Soda")
# Out:
#                          strDrink  \
# 0            Bailey's Dream Shake
# 1                    Belgian Blue
# 2                Bleeding Surgeon
# 3   Brandon and Will's Coke Float
# 4            California Root Beer
# 5                     Citrus Coke
# 6                  Coke and Drops
# 7                  Darkwood Sling
# 8                         Zambeer
# 9                          Zinger
# 10                         Zoksel
#
#                                         strDrinkThumb idDrink
# 0   https://www.thecocktaildb.com/images/media/dri...   14510
# 1   https://www.thecocktaildb.com/images/media/dri...   14071
# 2   https://www.thecocktaildb.com/images/media/dri...   16295
# 3   https://www.thecocktaildb.com/images/media/dri...   16447
# 4   https://www.thecocktaildb.com/images/media/dri...   14282
# 5   https://www.thecocktaildb.com/images/media/dri...   17135
# 6   https://www.thecocktaildb.com/images/media/dri...   17108
# 7   https://www.thecocktaildb.com/images/media/dri...   14482
# 8   https://www.thecocktaildb.com/images/media/dri...   15933
# 9   https://www.thecocktaildb.com/images/media/dri...   14888
# 10  https://www.thecocktaildb.com/images/media/dri...   15691

# %%
# needs to be exact
# list of different categories for this db
url_list_origin = "https://www.thecocktaildb.com/api/json/v1/1/list.php?c=list"
ra = requests.get(url_list_origin)
df = pd.DataFrame(ra.json()["drinks"])
df
# Out:
#              strCategory
# 0         Ordinary Drink
# 1               Cocktail
# 2   Milk / Float / Shake
# 3          Other/Unknown
# 4                  Cocoa
# 5                   Shot
# 6           Coffee / Tea
# 7       Homemade Liqueur
# 8    Punch / Party Drink
# 9                   Beer
# 10     Soft Drink / Soda
